# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('IPL Matches 2008-2020.csv')

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
d1=df.copy()
d1=d1.pivot_table('result_margin',columns='winner')
d1
# Out:
# winner         Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# result_margin             20.04717             17.0       19.352941
#
# winner         Delhi Daredevils  Gujarat Lions  Kings XI Punjab  \
# result_margin         14.179104       5.076923        15.564706
#
# winner         Kochi Tuskers Kerala  Kolkata Knight Riders  Mumbai Indians  \
# result_margin              8.833333               16.44898       20.847458
#
# winner         Pune Warriors  Rajasthan Royals  Rising Pune Supergiant  \
# result_margin      14.583333         15.379747                    15.4
#
# winner         Rising Pune Supergiants  Royal Challengers Bangalore  \
# result_margin                     14.6                    19.303371
#
# winner         Sunrisers Hyderabad
# result_margin            16.830769

# %%
n=df.groupby('winner').result_margin.max().sort_values(ascending=False)
n
# Out:
# winner
# Mumbai Indians                 146.0
# Royal Challengers Bangalore    144.0
# Kolkata Knight Riders          140.0
# Sunrisers Hyderabad            118.0
# Kings XI Punjab                111.0
# Rajasthan Royals               105.0
# Chennai Super Kings             97.0
# Delhi Daredevils                97.0
# Deccan Chargers                 82.0
# Rising Pune Supergiant          61.0
# Delhi Capitals                  59.0
# Pune Warriors                   38.0
# Rising Pune Supergiants         34.0
# Kochi Tuskers Kerala            17.0
# Gujarat Lions                    7.0
# Name: result_margin, dtype: float64

# %%
df['player_of_match'].value_counts()
# Out:
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
#                   ..
# S Anirudha         1
# M Kartik           1
# R McLaren          1
# RJ Harris          1
# PJ Cummins         1
# Name: player_of_match, Length: 233, dtype: int64

# %%
df['player_of_match'].nunique()
# Out:
# 233

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
d_1 = df[['team1','team2','winner','result_margin']].groupby(['team1','team2','winner']).max('result_margin')
d_1
# Out:
#                                                                              result_margin
# team1               team2                       winner
# Chennai Super Kings Deccan Chargers             Chennai Super Kings                   78.0
#                                                 Deccan Chargers                       31.0
#                     Delhi Capitals              Chennai Super Kings                   80.0
#                                                 Delhi Capitals                         5.0
#                     Delhi Daredevils            Chennai Super Kings                   93.0
# ...                                                                                    ...
# Sunrisers Hyderabad Rajasthan Royals            Sunrisers Hyderabad                   23.0
#                     Rising Pune Supergiant      Rising Pune Supergiant                12.0
#                     Rising Pune Supergiants     Rising Pune Supergiants               34.0
# ...

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df=df.drop(['method'],axis=1)

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
ven_grp = df.groupby('venue')
max_ven = ven_grp['winner','result_margin'].max().sort_values(by='result_margin',ascending=False)
max_ven
# Out:
#                                                     result_margin
# venue
# Feroz Shah Kotla                                            146.0
# M Chinnaswamy Stadium                                       144.0
# Rajiv Gandhi International Stadium, Uppal                   118.0
# Himachal Pradesh Cricket Association Stadium                111.0
# Wankhede Stadium                                            105.0
# Eden Gardens                                                102.0
# Dubai International Cricket Stadium                          97.0
# MA Chidambaram Stadium, Chepauk                              97.0
# Maharashtra Cricket Association Stadium                      97.0
# Sheikh Zayed Stadium                                         93.0
# St George's Park                                             92.0
# Sawai Mansingh Stadium                                       87.0
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...           85.0
# ...

# %%
n=df.groupby('winner').player_of_match.max()
n
# Out:
# winner
# Chennai Super Kings                      WP Saha
# Deccan Chargers                       WPUJC Vaas
# Delhi Capitals                           SS Iyer
# Delhi Daredevils                          Z Khan
# Gujarat Lions                            V Kohli
# Kings XI Punjab                     Yuvraj Singh
# Kochi Tuskers Kerala              P Parameswaran
# Kolkata Knight Riders                  YK Pathan
# Mumbai Indians                         YK Pathan
# Pune Warriors                          SPD Smith
# Rajasthan Royals                       YK Pathan
# Rising Pune Supergiant         Washington Sundar
# Rising Pune Supergiants                 MS Dhoni
# Royal Challengers Bangalore         Yuvraj Singh
# Sunrisers Hyderabad                 Yuvraj Singh
# Name: player_of_match, dtype: object

# %%
winner_wise = df.groupby('winner')
mean_res = winner_wise['winner','result_margin'].mean().sort_values(by='result_margin',ascending=False)
mean_res
# Out:
#                              result_margin
# winner
# Mumbai Indians                   20.847458
# Chennai Super Kings              20.047170
# Delhi Capitals                   19.352941
# Royal Challengers Bangalore      19.303371
# Deccan Chargers                  17.000000
# Sunrisers Hyderabad              16.830769
# Kolkata Knight Riders            16.448980
# Kings XI Punjab                  15.564706
# Rising Pune Supergiant           15.400000
# Rajasthan Royals                 15.379747
# Rising Pune Supergiants          14.600000
# Pune Warriors                    14.583333
# Delhi Daredevils                 14.179104
# Kochi Tuskers Kerala              8.833333
# Gujarat Lions                     5.076923

# %%
df.groupby("toss_decision").winner.value_counts()
# Out:
# toss_decision  winner
# bat            Chennai Super Kings            55
#                Mumbai Indians                 50
#                Kolkata Knight Riders          38
#                Rajasthan Royals               37
#                Royal Challengers Bangalore    31
#                Delhi Daredevils               29
#                Kings XI Punjab                24
#                Sunrisers Hyderabad            23
#                Deccan Chargers                14
#                Pune Warriors                   9
#                Delhi Capitals                  5
#                Gujarat Lions                   2
#                Rising Pune Supergiants         2
# field          Mumbai Indians                 70
#                Kings XI Punjab                64
#                Kolkata Knight Riders          61
#                Royal Challengers Bangalore    60
#                Chennai Super Kings            51
#                Rajasthan Royals               44
# ...

# %%
df['year'] = pd.DatetimeIndex(df['date']).year
df['year']
# Out:
# 0      2008
# 1      2008
# 2      2008
# 3      2008
# 4      2008
#        ...
# 811    2020
# 812    2020
# 813    2020
# 814    2020
# 815    2020
# Name: year, Length: 816, dtype: int64

# %%
df.groupby('winner').result.value_counts()
# Out:
# winner                       result
# Chennai Super Kings          runs       53
#                              wickets    53
# Deccan Chargers              runs       18
#                              wickets    11
# Delhi Capitals               runs        9
#                              wickets     8
#                              tie         2
# Delhi Daredevils             wickets    42
#                              runs       25
# Gujarat Lions                wickets    12
#                              runs        1
# Kings XI Punjab              wickets    45
#                              runs       40
#                              tie         3
# Kochi Tuskers Kerala         wickets     4
#                              runs        2
# Kolkata Knight Riders        wickets    57
#                              runs       41
#                              tie         1
# Mumbai Indians               runs       62
#                              wickets    56
# ...

# %%
teams_per_year = df.groupby('year')['winner'].value_counts()
teams_per_year
# Out:
# year  winner
# 2008  Rajasthan Royals               13
#       Kings XI Punjab                10
#       Chennai Super Kings             9
#       Delhi Daredevils                7
#       Mumbai Indians                  7
#                                      ..
# 2020  Kolkata Knight Riders           7
#       Royal Challengers Bangalore     7
#       Chennai Super Kings             6
#       Kings XI Punjab                 6
#       Rajasthan Royals                6
# Name: winner, Length: 108, dtype: int64

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df=df.drop(['id'],axis=1)

# %%
df
# Out:
#            city        date player_of_match  \
# 0     Bangalore  2008-04-18     BB McCullum
# 1    Chandigarh  2008-04-19      MEK Hussey
# 2         Delhi  2008-04-19     MF Maharoof
# 3        Mumbai  2008-04-20      MV Boucher
# 4       Kolkata  2008-04-20       DJ Hussey
# ..          ...         ...             ...
# 811       Dubai  2020-09-28  AB de Villiers
# 812       Dubai  2020-11-05       JJ Bumrah
# 813   Abu Dhabi  2020-11-06   KS Williamson
# 814   Abu Dhabi  2020-11-08      MP Stoinis
# 815       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ...

# %%
df.drop(['umpire1','umpire2'],axis=1,inplace=True)
df
# Out:
#            city        date player_of_match  \
# 0     Bangalore  2008-04-18     BB McCullum
# 1    Chandigarh  2008-04-19      MEK Hussey
# 2         Delhi  2008-04-19     MF Maharoof
# 3        Mumbai  2008-04-20      MV Boucher
# 4       Kolkata  2008-04-20       DJ Hussey
# ..          ...         ...             ...
# 811       Dubai  2020-09-28  AB de Villiers
# 812       Dubai  2020-11-05       JJ Bumrah
# 813   Abu Dhabi  2020-11-06   KS Williamson
# 814   Abu Dhabi  2020-11-08      MP Stoinis
# 815       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ...

# %%
df.isnull()
# Out:
#       city   date  player_of_match  venue  neutral_venue  team1  team2  \
# 0    False  False            False  False          False  False  False
# 1    False  False            False  False          False  False  False
# 2    False  False            False  False          False  False  False
# 3    False  False            False  False          False  False  False
# 4    False  False            False  False          False  False  False
# ..     ...    ...              ...    ...            ...    ...    ...
# 811  False  False            False  False          False  False  False
# 812  False  False            False  False          False  False  False
# 813  False  False            False  False          False  False  False
# 814  False  False            False  False          False  False  False
# 815  False  False            False  False          False  False  False
#
#      toss_winner  toss_decision  winner  result  result_margin  eliminator  \
# ...

# %%
df.isnull().sum()
# Out:
# city               13
# date                0
# player_of_match     4
# venue               0
# neutral_venue       0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# winner              4
# result              4
# result_margin      17
# eliminator          4
# year                0
# dtype: int64

# %%
winner_per_year = df.groupby(['winner','year'])['result'].value_counts()
winner_per_year
# Out:
# winner               year  result
# Chennai Super Kings  2008  runs       5
#                            wickets    4
#                      2009  runs       6
#                            wickets    2
#                      2010  runs       5
#                                      ..
# Sunrisers Hyderabad  2018  wickets    5
#                      2019  wickets    4
#                            runs       2
#                      2020  runs       4
#                            wickets    4
# Name: result, Length: 220, dtype: int64

# %%
d2=df.copy()
d2=d2.pivot_table('result',columns='winner')
d2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df
# Out:
#            city        date player_of_match  \
# 0     Bangalore  2008-04-18     BB McCullum
# 1    Chandigarh  2008-04-19      MEK Hussey
# 2         Delhi  2008-04-19     MF Maharoof
# 3        Mumbai  2008-04-20      MV Boucher
# 4       Kolkata  2008-04-20       DJ Hussey
# ..          ...         ...             ...
# 811       Dubai  2020-09-28  AB de Villiers
# 812       Dubai  2020-11-05       JJ Bumrah
# 813   Abu Dhabi  2020-11-06   KS Williamson
# 814   Abu Dhabi  2020-11-08      MP Stoinis
# 815       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ...

# %%
df.head()
# Out:
#          city        date player_of_match  \
# 0   Bangalore  2008-04-18     BB McCullum
# 1  Chandigarh  2008-04-19      MEK Hussey
# 2       Delhi  2008-04-19     MF Maharoof
# 3      Mumbai  2008-04-20      MV Boucher
# 4     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# 3               Mumbai Indians  Royal Challengers Bangalore
# ...

# %%
df.pivot_table('toss_decision',columns='year',aggfunc='max')
# Out:
# year            2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# toss_decision  field  field  field  field  field  field  field  field  field
#
# year            2017   2018   2019   2020
# toss_decision  field  field  field  field

# %%
print(df['winner'].value_counts())
plt.figure(figsize=(15,4))
sns.countplot(x=df['winner'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
df.groupby(['winner','year'])['result'].value_counts()

# %%
plt.title('Winner',fontsize=20)
df['winner'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True,figsize=(12,12))
plt.show()

# %%
d3=df.sample(20)
d3
# Out:
#                city        date   player_of_match  \
# 330          Mumbai  2013-04-09        KD Karthik
# 557       Bangalore  2016-05-11         KH Pandya
# 704      Chandigarh  2019-03-30        MA Agarwal
# 165      Dharamsala  2010-04-16         RG Sharma
# 238          Mumbai  2011-05-19         YK Pathan
# 198         Kolkata  2011-04-22          CH Gayle
# 4           Kolkata  2008-04-20         DJ Hussey
# 536            Pune  2016-04-24          SA Yadav
# 55           Mumbai  2008-05-30         SR Watson
# 134          Mumbai  2010-03-25      SR Tendulkar
# 399             NaN  2014-04-17         YS Chahal
# 454         Kolkata  2014-05-27          UT Yadav
# 72   Port Elizabeth  2009-04-27      SR Tendulkar
# 812           Dubai  2020-11-05         JJ Bumrah
# 121       Bangalore  2010-03-16         JH Kallis
# 531          Rajkot  2016-04-21           B Kumar
# 152          Jaipur  2010-04-07           MJ Lumb
# 437         Cuttack  2014-05-14        RV Uthappa
# ...

# %%
plt.bar(d3['winner'],d3['result_margin'])
plt.title('winner Vs margin',fontsize=15,color='red')
plt.xlabel('winner',fontsize=15)
plt.ylabel('margin',fontsize=15)
plt.grid(True)
plt.show()

# %%
d3=df.sample(20)
plt.figure(figsize=(18,6))
plt.bar('winner','result_margin', data=d3,color='green')
plt.show()

# %%
plt.bar(d3['winner'],d3['result_margin'],color="red")
plt.title('winner Vs result_margin',fontsize=15,color='blue')
plt.xlabel('winner',fontsize=15)
plt.ylabel('result_margin',fontsize=15)
plt.grid(True)
plt.show()
